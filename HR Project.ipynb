# %%
import pandas as pd
import numpy as np
emp=pd.read_csv('HR-Employee-Attrition.csv')

# %%
emp.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %% [markdown]
# ### Observed:

# %% [raw]
# -> Attrition is our target variable
# -> There are so many cloumns let us do EDA for better understanding

# %%
#let us check data types
emp.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %% [markdown]
# ### Observed:

# %% [raw]
# -> 9 Types of data are Objects
# -> Remaining all are int type

# %%
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# ### Observed:

# %% [raw]
# -> There are 1470 columns and 35 rows

# %%
emp.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
for column in emp.columns:
    print(f"{column}: Number of unique values {emp[column].nunique()}")
    print('------------------------------------------------------------')
# Out:
# Age: Number of unique values 43
# ------------------------------------------------------------
# Attrition: Number of unique values 2
# ------------------------------------------------------------
# BusinessTravel: Number of unique values 3
# ------------------------------------------------------------
# DailyRate: Number of unique values 886
# ------------------------------------------------------------
# Department: Number of unique values 3
# ------------------------------------------------------------
# DistanceFromHome: Number of unique values 29
# ------------------------------------------------------------
# Education: Number of unique values 5
# ------------------------------------------------------------
# EducationField: Number of unique values 6
# ------------------------------------------------------------
# EmployeeCount: Number of unique values 1
# ------------------------------------------------------------
# EmployeeNumber: Number of unique values 1470
# ...

# %% [markdown]
# ### Observed:

# %% [raw]
# -> We can Observe that in columns like Employee
# count,Over18,StandardHours have only 1 value so there not useful

# %%
# let us drop above mentioned columns
emp1=emp.drop(['EmployeeCount', 'EmployeeNumber', 'Over18', 'StandardHours'], axis=1)

# %%
emp1.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          2  Life Sciences                        2
# 1                 8          1  Life Sciences                        3
# 2                 2          2          Other                        4
# 3                 3          4  Life Sciences                        4
# 4                 2          1        Medical                        1
#
#    Gender  ...  PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# ...

# %%
emp1.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  \
# count  1470.000000  1470.000000       1470.000000  1470.000000
# mean     36.923810   802.485714          9.192517     2.912925
# std       9.135373   403.509100          8.106864     1.024165
# min      18.000000   102.000000          1.000000     1.000000
# 25%      30.000000   465.000000          2.000000     2.000000
# 50%      36.000000   802.000000          7.000000     3.000000
# 75%      43.000000  1157.000000         14.000000     4.000000
# max      60.000000  1499.000000         29.000000     5.000000
#
#        EnvironmentSatisfaction   HourlyRate  JobInvolvement     JobLevel  \
# count              1470.000000  1470.000000     1470.000000  1470.000000
# mean                  2.721769    65.891156        2.729932     2.063946
# std                   1.093082    20.329428        0.711561     1.106940
# min                   1.000000    30.000000        1.000000     1.000000
# ...

# %% [markdown]
# ### Observed:

# %% [raw]
# -> We can observe that in columns Age,DailyRate,HourlyRate there is a huge difference between mean and Std
# -> And in some columns like monthlyincome,TotalWorkingYears,YearsAtCompany,YearsAtCompany,YearsSinceLastPromotion there is a huge difference between 75% and maximum value

# %% [markdown]
# ## Checking for missing values

# %%
#using heatmap to check null values
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(emp1.isnull())
plt.show()

# %% [raw]
# -> We can observe that There are no null values from heatmap

# %%
emp=emp1.corr()
emp
# Out:
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000   0.010661         -0.001686   0.208034
# DailyRate                 0.010661   1.000000         -0.004985  -0.016806
# DistanceFromHome         -0.001686  -0.004985          1.000000   0.021042
# Education                 0.208034  -0.016806          0.021042   1.000000
# EnvironmentSatisfaction   0.010146   0.018355         -0.016075  -0.027128
# HourlyRate                0.024287   0.023381          0.031131   0.016775
# JobInvolvement            0.029820   0.046135          0.008783   0.042438
# JobLevel                  0.509604   0.002966          0.005303   0.101589
# JobSatisfaction          -0.004892   0.030571         -0.003669  -0.011296
# MonthlyIncome             0.497855   0.007707         -0.017014   0.094961
# MonthlyRate               0.028051  -0.032182          0.027473  -0.026084
# ...

# %%
plt.figure(figsize=(20,20))
sns.heatmap(emp,annot=True,cmap='winter')

# %% [markdown]
# ### Observed:

# %% [raw]
# -> most of data is highly correlated we will drop columns which are highly correlated

# %%
emphr=emp1.drop(['Age','DailyRate','DistanceFromHome','EnvironmentSatisfaction','HourlyRate','JobInvolvement', 'JobLevel','JobSatisfaction','RelationshipSatisfaction','StockOptionLevel','TrainingTimesLastYear'],axis=1)

# %%
#After droping highly correlated columns
emphr
# Out:
#      Attrition     BusinessTravel              Department  Education  \
# 0          Yes      Travel_Rarely                   Sales          2
# 1           No  Travel_Frequently  Research & Development          1
# 2          Yes      Travel_Rarely  Research & Development          2
# 3           No  Travel_Frequently  Research & Development          4
# 4           No      Travel_Rarely  Research & Development          1
# ...        ...                ...                     ...        ...
# 1465        No  Travel_Frequently  Research & Development          2
# 1466        No      Travel_Rarely  Research & Development          1
# 1467        No      Travel_Rarely  Research & Development          3
# 1468        No  Travel_Frequently                   Sales          3
# 1469        No      Travel_Rarely  Research & Development          3
#
#      EducationField  Gender                    JobRole MaritalStatus  \
# ...

# %%
# let us use LebelEncoder to convert categorical variable
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
list1=['Attrition','BusinessTravel','Department','EducationField','MaritalStatus','OverTime','Gender','JobRole']
for val in list1:
    emphr[val]=le.fit_transform(emphr[val])

# %%
emphr
# Out:
#       Attrition  BusinessTravel  Department  Education  EducationField  \
# 0             1               2           2          2               1
# 1             0               1           1          1               1
# 2             1               2           1          2               4
# 3             0               1           1          4               1
# 4             0               2           1          1               3
# ...         ...             ...         ...        ...             ...
# 1465          0               1           1          2               3
# 1466          0               2           1          1               3
# 1467          0               2           1          3               1
# 1468          0               1           2          3               3
# 1469          0               2           1          3               3
#
#       Gender  JobRole  MaritalStatus  MonthlyIncome  MonthlyRate  \
# ...

# %%
emphr.dtypes
# Out:
# Attrition                  int32
# BusinessTravel             int32
# Department                 int32
# Education                  int64
# EducationField             int32
# Gender                     int32
# JobRole                    int32
# MaritalStatus              int32
# MonthlyIncome              int64
# MonthlyRate                int64
# NumCompaniesWorked         int64
# OverTime                   int32
# PercentSalaryHike          int64
# PerformanceRating          int64
# TotalWorkingYears          int64
# WorkLifeBalance            int64
# YearsAtCompany             int64
# YearsInCurrentRole         int64
# YearsSinceLastPromotion    int64
# YearsWithCurrManager       int64
# dtype: object

# %% [markdown]
# ### Observed:

# %% [raw]
# -> No=0 and yes=1 in Attrition
# -> No=1 and yes=1 in overtime
# -> NO=F and yes=M in Gender

# %%
plt.figure(figsize=(5,5))
emphr['Attrition'].plot.hist()
plt.show()

# %% [markdown]
# ### Observed:

# %% [raw]
# -> There more no of No's than Yes

# %%
sns.barplot(x='Attrition',y='MonthlyIncome',data=emphr)
plt.show()

# %%
sns.countplot(x='Attrition',hue='Gender',data=emphr)
plt.show()

# %% [markdown]
# #### Observed:

# %% [raw]
# -> In Gender 0's are more than 1's

# %%
sns.barplot(x='Department',y='MonthlyIncome',data=emphr)

# %% [markdown]
# ### Observed:

# %% [raw]
# -> Almost all departments monthly income is same

# %%
sns.countplot(x='JobRole',hue='Attrition',data=emphr)
plt.show()

# %%
sns.barplot(x='Attrition',y='NumCompaniesWorked',data=emphr)
plt.show()

# %% [markdown]
# ### Observed:

# %% [raw]
# -> There more of 1's than 0's

# %%
plt.figure(figsize=(10,10))
sns.set(style='white')
plt.scatter(emphr['MonthlyRate'],emphr['MonthlyIncome'])
plt.xlabel('MonthlyRate')
plt.ylabel('MonthlyIncome')
plt.show()

# %% [markdown]
# ### Observed:

# %% [raw]
# -> Data is spread all over

# %%
#in PerformanceRatig there some unknown string And Attrition is our target variable 
emphr1=emphr.drop(['Attrition','PerformanceRating'],axis=1)

# %% [markdown]
# ## To Check the Distribution of Skewness

# %%
emphr1.skew()
# Out:
# BusinessTravel            -1.439006
# Department                 0.172231
# Education                 -0.289681
# EducationField             0.550371
# Gender                    -0.408665
# JobRole                   -0.357270
# MaritalStatus             -0.152175
# MonthlyIncome              1.369817
# MonthlyRate                0.018578
# NumCompaniesWorked         1.026471
# OverTime                   0.964489
# PercentSalaryHike          0.821128
# TotalWorkingYears          1.117172
# WorkLifeBalance           -0.552480
# YearsAtCompany             1.764529
# YearsInCurrentRole         0.917363
# YearsSinceLastPromotion    1.984290
# YearsWithCurrManager       0.833451
# dtype: float64

# %%
collist=emphr1.columns.values
ncol=15
nrow=15
plt.figure(figsize=(50,30))
for i in range(0,len(collist)):
    plt.subplot(nrow,ncol,i+1)
    sns.distplot(emphr1[collist[i]],color='red')
    plt.tight_layout()
import warnings
warnings.filterwarnings('ignore')

# %%
collist=emphr1.columns.values
ncol=15
nrow=10
for i in emphr1.columns:
    sns.distplot(emphr1[i])
    plt.show()

# %%
#Treating skewness via log method
for col in emphr1.columns:
    if emphr1[col].skew()>0.55:
        emphr1[col]=np.log1p(emphr[col])

# %%
emphr1.skew()
# Out:
# BusinessTravel            -1.439006
# Department                 0.172231
# Education                 -0.289681
# EducationField            -0.054786
# Gender                    -0.408665
# JobRole                   -0.357270
# MaritalStatus             -0.152175
# MonthlyIncome              0.286448
# MonthlyRate                0.018578
# NumCompaniesWorked         0.092896
# OverTime                   0.964489
# PercentSalaryHike          0.513543
# TotalWorkingYears         -0.622175
# WorkLifeBalance           -0.552480
# YearsAtCompany            -0.207708
# YearsInCurrentRole        -0.383498
# YearsSinceLastPromotion    0.718805
# YearsWithCurrManager      -0.357686
# dtype: float64

# %%
emp1=pd.DataFrame(emphr1)
emp2=pd.DataFrame(emphr['Attrition'])

# %%
#Has we can observe that there is no target variable
emp1.head()
# Out:
#    BusinessTravel  Department  Education  EducationField  Gender  JobRole  \
# 0               2           2          2        0.693147       0        7
# 1               1           1          1        0.693147       1        6
# 2               2           1          2        1.609438       1        2
# 3               1           1          4        0.693147       0        6
# 4               2           1          1        1.386294       1        2
#
#    MaritalStatus  MonthlyIncome  MonthlyRate  NumCompaniesWorked  OverTime  \
# 0              2       8.698514        19479            2.197225  0.693147
# 1              1       8.543056        24907            0.693147  0.000000
# 2              2       7.645398         2396            1.945910  0.693147
# 3              1       7.975908        23159            0.693147  0.693147
# 4              1       8.151622        16632            2.302585  0.000000
#
# ...

# %%
#This is our taget variable to removw outliers we have to merge with emp1
emp2
# Out:
#       Attrition
# 0             1
# 1             0
# 2             1
# 3             0
# 4             0
# ...         ...
# 1465          0
# 1466          0
# 1467          0
# 1468          0
# 1469          0
#
# [1470 rows x 1 columns]

# %%
# Merging emp1 and emp2
emphr_final=pd.concat([emp1,emp2],axis=1)
emphr_final.head()
# Out:
#    BusinessTravel  Department  Education  EducationField  Gender  JobRole  \
# 0               2           2          2        0.693147       0        7
# 1               1           1          1        0.693147       1        6
# 2               2           1          2        1.609438       1        2
# 3               1           1          4        0.693147       0        6
# 4               2           1          1        1.386294       1        2
#
#    MaritalStatus  MonthlyIncome  MonthlyRate  NumCompaniesWorked  OverTime  \
# 0              2       8.698514        19479            2.197225  0.693147
# 1              1       8.543056        24907            0.693147  0.000000
# 2              2       7.645398         2396            1.945910  0.693147
# 3              1       7.975908        23159            0.693147  0.693147
# 4              1       8.151622        16632            2.302585  0.000000
#
# ...

# %% [markdown]
# ## Checking for outliers

# %%
#let us check outliers for all columns
col=emphr_final.columns.values
ncol=10
nrow=10
plt.figure(figsize=(ncol,5*ncol))
for i in  range(1,len(col)):
    plt.subplot(nrow,ncol,i+1)
    sns.boxplot(emphr_final[col[i]],color='green',orient='v')
    plt.tight_layout()

# %% [markdown]
# ### Observed:

# %% [raw]
# -> Columns like TotalWorkingYears,YearsAtCompany, and in some other columns we have outliers

# %% [markdown]
# ## Removing Outliers

# %%
#Removing outliers
from scipy.stats import zscore
z_score=abs(zscore(emphr_final))
print(emphr_final.shape)
emp=emphr_final.loc[(z_score<3).all(axis=1)]
print(emp.shape)
# Out:
# (1470, 19)
# (1459, 19)

# %% [markdown]
# ### Observed:

# %% [raw]
# -> 21 Rows are removed as outliers
# -> Outliers are removed

# %% [markdown]
# # Model Training

# %%
emp.head()
# Out:
#    BusinessTravel  Department  Education  EducationField  Gender  JobRole  \
# 0               2           2          2        0.693147       0        7
# 1               1           1          1        0.693147       1        6
# 2               2           1          2        1.609438       1        2
# 3               1           1          4        0.693147       0        6
# 4               2           1          1        1.386294       1        2
#
#    MaritalStatus  MonthlyIncome  MonthlyRate  NumCompaniesWorked  OverTime  \
# 0              2       8.698514        19479            2.197225  0.693147
# 1              1       8.543056        24907            0.693147  0.000000
# 2              2       7.645398         2396            1.945910  0.693147
# 3              1       7.975908        23159            0.693147  0.693147
# 4              1       8.151622        16632            2.302585  0.000000
#
# ...

# %%
#Seprating into input and output variables
df_x=emp.drop(['Attrition'],axis=1)

# %%
y=pd.DataFrame(emp['Attrition'])

# %%
df_x.head()
# Out:
#    BusinessTravel  Department  Education  EducationField  Gender  JobRole  \
# 0               2           2          2        0.693147       0        7
# 1               1           1          1        0.693147       1        6
# 2               2           1          2        1.609438       1        2
# 3               1           1          4        0.693147       0        6
# 4               2           1          1        1.386294       1        2
#
#    MaritalStatus  MonthlyIncome  MonthlyRate  NumCompaniesWorked  OverTime  \
# 0              2       8.698514        19479            2.197225  0.693147
# 1              1       8.543056        24907            0.693147  0.000000
# 2              2       7.645398         2396            1.945910  0.693147
# 3              1       7.975908        23159            0.693147  0.693147
# 4              1       8.151622        16632            2.302585  0.000000
#
# ...

# %%
y.head()
# Out:
#    Attrition
# 0          1
# 1          0
# 2          1
# 3          0
# 4          0

# %%
#scaling the input variable
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(df_x)
x=pd.DataFrame(x,columns=df_x.columns)

# %%
x.shape
# Out:
# (1459, 18)

# %%
y.shape
# Out:
# (1459, 1)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### GridSearchCV

# %%
from sklearn import svm
svc=svm.SVC()
parameters={'kernel':['linear','rbf','poly'],'C':[1.0]}
gd=GridSearchCV(svc,parameters)
gd.fit(x,y)
sorted(gd.cv_results_.keys())
print(gd.best_params_)
# Out:
# {'C': 1.0, 'kernel': 'rbf'}

# %% [markdown]
# #### Observed:

# %% [raw]
# -> c=1 and kernel='rbf' are best parameters for SVC

# %%
dtc=DecisionTreeClassifier()
parameters={'criterion':['gini','entropy']}
gd=GridSearchCV(dtc,parameters)
gd.fit(x,y)
sorted(gd.cv_results_.keys())
print(gd.best_params_)
# Out:
# {'criterion': 'entropy'}

# %% [markdown]
# #### Observed:

# %% [raw]
# -> Criterion=entropy is best parameter for DecisionTreeCkassifier

# %% [markdown]
# #### Training our models is cross_val_score  so that they won't overfit or underfit

# %%
from sklearn.model_selection import cross_val_score
model=[DecisionTreeClassifier(criterion='gini'),KNeighborsClassifier(),SVC(kernel='rbf'),RandomForestClassifier(),AdaBoostClassifier()]
for m in model:
    score=cross_val_score(m,x,y,cv=5)
    print('Score of',m,'is:',score)
    print('Mean score:',score.mean())
    print('Standard deviation:',score.std())
    print('*******************************************************************************************************')
    print('\n')
# Out:
# Score of DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best') is: [0.78082192 0.76027397 0.82876712 0.76369863 0.77319588]
# Mean score: 0.7813515040248553
# Standard deviation: 0.02478274384631308
# *******************************************************************************************************
#
#
# Score of KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform') is: [0.83219178 0.85273973 0.84589041 0.8630137  0.85910653]
# Mean score: 0.8505884291295956
# ...

# %% [markdown]
# ### Observed:

# %% [raw]
# -> All the data is well trained

# %% [markdown]
# #### predicting the best accuracy score

# %%
max_accuracy_score=0
for r_state in range (40,1400):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=.20)
    model=[DecisionTreeClassifier(criterion='gini'),KNeighborsClassifier(),SVC(kernel='rbf'),RandomForestClassifier(),AdaBoostClassifier()]
    for m in model:
        m.fit(x_train,y_train)
        y_pred=m.predict(x_test)
        r_scr=accuracy_score(y_test,y_pred)
        if r_scr>max_accuracy_score:
            max_accuracy_score=r_scr
            final_r_state=r_state
print("max accuracy score corresponding to ",final_r_state,"is",max_accuracy_score)
# Out:
# max accuracy score corresponding to  272 is 0.9143835616438356

# %% [markdown]
# #### Observed

# %% [raw]
# -> Max accuracy score from all models corresponding to 272 is 0.91

# %% [markdown]
# ## Predicting Best Model

# %%
model=[LogisticRegression(),DecisionTreeClassifier(criterion='entropy'),KNeighborsClassifier(),SVC(kernel='rbf'),RandomForestClassifier(),AdaBoostClassifier()]
for m in model:
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=272,test_size=.20)
    m.fit(x_train,y_train)
    print('Score of',m,'is:',m.score(x_train,y_train))
    predm=m.predict(x_test)
    print('Score:')
    print('accuracy_score :',accuracy_score(y_test,predm))
    print('confusion_matrix :',confusion_matrix(y_test,predm))
    print('classification_report',classification_report(y_test,predm))
    print('*******************************************************************************************************')
    print('\n')
# Out:
# Score of LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False) is: 0.8534704370179949
# Score:
# accuracy_score : 0.9178082191780822
# confusion_matrix : [[259   1]
#  [ 23   9]]
# classification_report               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96       260
#            1       0.90      0.28      0.43        32
#
#     accuracy                           0.92       292
#    macro avg       0.91      0.64      0.69       292
# weighted avg       0.92      0.92      0.90       292
#
# *******************************************************************************************************
#
#
# ...

# %% [markdown]
# ### observed:

# %% [raw]
# 1) Score of LogisticRegression       = 85% and accuracy score = 91%
# 2) score of DecisionTreeClassifier   = 100% and accuracy score = 79%
# 3) score of KNeighborsClassifier     = 86% and accuracy score = 88%
# 4) Score of SVC                      = 87% and accuracy score = 89%
# 5) Score of RandomForestClassifier   = 100% and accuracy socre = 89%
# 6) Score of AdaBoostClassifier       = 86% and accuracy score = 89%

# %% [raw]
# -> If accuracy score is more then errors will be less as observed above among all models LogisticRegression  gives Score of LogisticRegression  as 85% and accuracy score as 91% .Hance we select LogisticRegression  as our best model.

# %% [markdown]
# ## Saving the best model

# %%
#LogisticRegression  is best model among all models
import joblib
joblib.dump(LogisticRegression ,'HR_final.pkl')
# Out:
# ['HR_final.pkl']
